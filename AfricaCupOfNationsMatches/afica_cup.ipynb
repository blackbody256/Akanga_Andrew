# %%
import pandas as pd

df = pd.read_csv('AfricaCupofNationsMatches.csv')

# %%
df.head(7)
# Out:
#    Year      Date  Time    HomeTeam       AwayTeam  HomeTeamGoals  \
# 0  1957  10-Feb-57   NaN     Sudan           Egypt            1.0
# 1  1957  10-Feb-57   NaN  Ethiopia    South Africa            NaN
# 2  1957  16-Feb-57   NaN     Egypt        Ethiopia            4.0
# 3  1959  22-May-59   NaN      Egypt       Ethiopia            4.0
# 4  1959  25-May-59   NaN     Sudan        Ethiopia            1.0
# 5  1959  29-May-59   NaN      Egypt          Sudan            2.0
# 6  1962  14-Jan-62   NaN  Ethiopia         Tunisia            4.0
#
#    AwayTeamGoals             Stage  \
# 0            2.0        Semifinals
# 1            NaN        Semifinals
# 2            0.0             Final
# 3            0.0  Final Tournament
# 4            0.0  Final Tournament
# 5            1.0  Final Tournament
# 6            2.0        Semifinals
#
#                                 SpecialWinConditions                 Stadium  \
# ...

# %%
new_df = df[['HomeTeam','AwayTeam','HomeTeamGoals','AwayTeamGoals']]
new_df
# Out:
#         HomeTeam       AwayTeam  HomeTeamGoals  AwayTeamGoals
# 0         Sudan           Egypt            1.0            2.0
# 1      Ethiopia    South Africa            NaN            NaN
# 2         Egypt        Ethiopia            4.0            0.0
# 3          Egypt       Ethiopia            4.0            0.0
# 4         Sudan        Ethiopia            1.0            0.0
# ..           ...            ...            ...            ...
# 617  Madagascar         Tunisia            0.0            3.0
# 618     Senegal         Tunisia            1.0            0.0
# 619     Algeria         Nigeria            2.0            1.0
# 620     Tunisia         Nigeria            0.0            1.0
# 621     Senegal         Algeria            0.0            1.0
#
# [622 rows x 4 columns]

# %%
egypt_df = new_df[(new_df['HomeTeam'] == 'Egypt') | (new_df['AwayTeam'] == 'Egypt')]
egypt_df
# Out:
#      HomeTeam   AwayTeam  HomeTeamGoals  AwayTeamGoals
# 3       Egypt   Ethiopia            4.0            0.0
# 5       Egypt      Sudan            2.0            1.0
# 7       Egypt     Uganda            2.0            1.0
# 9   Ethiopia       Egypt            4.0            2.0
# 13      Egypt    Nigeria            6.0            3.0
# 14      Egypt      Sudan            2.0            2.0
# 16      Egypt   Ethiopia            3.0            0.0

# %%
new_df.shape
# Out:
# (622, 4)

# %%
no_attendence_df = df[df['Attendance'].isnull]
no_attendence_df
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 no_attendence_df = df[df['Attendance'].isnull]
#       2 no_attendence_df
#
# File ~/miniconda3/envs/DataScience/lib/python3.13/site-packages/pandas/core/frame.py:4065, in DataFrame.__getitem__(self, key)
#    4063 check_dict_or_set_indexers(key)
#    4064 key = lib.item_from_zerodim(key)
# -> 4065 key = com.apply_if_callable(key, self)
#    4067 if is_hashable(key) and not is_iterator(key):
#    4068     # is_iterator to exclude generator e.g. test_getitem_listlike
#    4069     # shortcut if the key is in columns
#    4070     is_mi = isinstance(self.columns, MultiIndex)
#
# File ~/miniconda3/envs/DataScience/lib/python3.13/site-packages/pandas/core/common.py:384, in apply_if_callable(maybe_callable, obj, **kwargs)
#     373 """
# ...
